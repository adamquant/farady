# %%
from farady import calculate_from_dict

case = {'zawja':1, 'umm':1, "bint": 2}

calculate_from_dict(case)
# Out:
# [2026-02-27 00:34:29] INFO: === Calculation Started ===
#     case_input:
#     case: {'bint': 2, 'umm': 1, 'zawja': 1}
# Case(ibn={}, bint={'count': 2, 'fard': Fraction(2, 3), 'shares': 28}, iibn={}, bibn={}, iiibn={}, biibn={}, umm={'count': 1, 'fard': Fraction(1, 6), 'shares': 7}, jadda={}, ab={}, jadd={}, lium={}, shaqiqa={}, shaqiq={}, uliab={}, aliab={}, ibnamm_sh={}, ibnamm_liab={}, amm={}, zawj={}, zawja={'count': 1, 'fard': Fraction(1, 8), 'shares': 5}, ending='radd', asib=None, status='Complete', heads=None, _raas_override=40, radd_heirs=[('bint', {'count': 2, 'fard': Fraction(2, 3), 'shares': 28}, 16), ('umm', {'count': 1, 'fard': Fraction(1, 6), 'shares': 7}, 4)], total_shares_radd=20, shaqiqa_taking_half=None, shaqiqas_taking_twothirds=None, bint_taking_half=None, bints_taking_twothirds=True)

# %%
from distribution_v1 import calculate

case = {'zawja':1, 'umm':1, "bint": 2}


calculate(case)
# Out:
# ({},
#  {'zawja': Fraction(1, 8), 'umm': Fraction(7, 40), 'bint': Fraction(7, 10)},
#  'radd',
#  None,
#  Fraction(1, 1),
#  'Complete')
